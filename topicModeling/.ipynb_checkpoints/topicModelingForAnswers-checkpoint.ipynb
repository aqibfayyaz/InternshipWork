# %%
from pycaret.nlp import *
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
from nltk.corpus import stopwords
stopWords = stopwords.words('english')

# %%
import pandas as pd


# load the data into a dataframe
data = pd.read_csv('20200325_counsel_chat.csv')
data.head()
# Out:
#    Unnamed: 0  questionID                                      questionTitle  \
# 0           0           0  Can I change my feeling of being worthless to ...
# 1           1           0  Can I change my feeling of being worthless to ...
# 2           2           0  Can I change my feeling of being worthless to ...
# 3           3           0  Can I change my feeling of being worthless to ...
# 4           4           0  Can I change my feeling of being worthless to ...
#
#                                         questionText  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                         questionLink       topic  \
# 0  https://counselchat.com/questions/can-i-change...  depression
# 1  https://counselchat.com/questions/can-i-change...  depression
# 2  https://counselchat.com/questions/can-i-change...  depression
# 3  https://counselchat.com/questions/can-i-change...  depression
# 4  https://counselchat.com/questions/can-i-change...  depression
#
#                                        therapistInfo  \
# 0  Sherry Katz, LCSWCouples and Family Therapist,...
# 1  Robin Landwehr, DBH, LPCC, NCCMental Health in...
# 2  Lee KingI use an integrative approach to treat...
# 3  Shauntai Davis-YearginPersonalized, private on...
# 4  Jordan WhiteLicensed Social Worker at Oak Root...
#
#                                         therapistURL  \
# 0  https://counselchat.com/therapists/sherry-katz...
# 1  https://counselchat.com/therapists/robin-landw...
# 2        https://counselchat.com/therapists/lee-king
# 3  https://counselchat.com/therapists/shauntai-da...
# 4    https://counselchat.com/therapists/jordan-white
#
#                                           answerText  upvotes  views  split
# 0  If everyone thinks you're worthless, then mayb...        1   2899  train
# 1  Hello, and thank you for your question and see...        1   3514  train
# 2  First thing I'd suggest is getting the sleep y...        0      5  train
# 3  Therapy is essential for those that are feelin...        0     31  train
# 4  I first want to let you know that you are not ...        0    620  train

# %%
data['answers_without_stopwords'] = data['answerText'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopWords)]))
data['answerText'] = data['answers_without_stopwords']
data['answerText'].head()
# Out:
# 0    If everyone thinks worthless, maybe need find ...
# 1    Hello, thank question seeking advice this. Fee...
# 2    First thing I'd suggest getting sleep need imp...
# 3    Therapy essential feeling depressed worthless....
# 4    I first want let know alone feelings always so...
# Name: answerText, dtype: object

# %%
data.tail()
# Out:
#       Unnamed: 0  questionID                          questionTitle  \
# 2124        2124          20  What happens in a counseling session?
# 2125        2125          20  What happens in a counseling session?
# 2126        2126          20  What happens in a counseling session?
# 2127        2127          20  What happens in a counseling session?
# 2128        2128          20  What happens in a counseling session?
#
#                                            questionText  \
# 2124  After first meeting the client, what is the pr...
# 2125  After first meeting the client, what is the pr...
# 2126  After first meeting the client, what is the pr...
# 2127  After first meeting the client, what is the pr...
# 2128  After first meeting the client, what is the pr...
#
#                                            questionLink  \
# 2124  https://counselchat.com/questions/what-happens...
# 2125  https://counselchat.com/questions/what-happens...
# 2126  https://counselchat.com/questions/what-happens...
# 2127  https://counselchat.com/questions/what-happens...
# 2128  https://counselchat.com/questions/what-happens...
#
#                         topic  \
# 2124  counseling-fundamentals
# 2125  counseling-fundamentals
# 2126  counseling-fundamentals
# 2127  counseling-fundamentals
# 2128  counseling-fundamentals
#
#                                           therapistInfo  \
# 2124       Victoria HaagFind direction for your life...
# 2125        Allison VelezIs your relationship worth it?
# 2126  David RouttPresident and Clinical Counselor at...
# 2127  2nd Chance Counseling Service Online Addiction...
# 2128  Sherry Katz, LCSWCouples and Family Therapist,...
#
#                                            therapistURL  \
# 2124   https://counselchat.com/therapists/victoria-haag
# 2125   https://counselchat.com/therapists/allison-velez
# 2126     https://counselchat.com/therapists/david-routt
# 2127  https://counselchat.com/therapists/2nd-chance-...
# 2128  https://counselchat.com/therapists/sherry-katz...
#
#                                              answerText  upvotes  views  \
# 2124  There probably two therapists alike first fore...        0     45
# 2125  Each counselor may different process, I'm end ...        0     37
# 2126  After meeting client, many Counselors ask lots...        0     56
# 2127  A good therapist discuss brought therapy first...        0     27
# 2128  Great question I imagine many people well.The ...        0     25
#
#       split                          answers_without_stopwords
# 2124  train  There probably two therapists alike first fore...
# 2125  train  Each counselor may different process, I'm end ...
# 2126  train  After meeting client, many Counselors ask lots...
# 2127  train  A good therapist discuss brought therapy first...
# 2128  train  Great question I imagine many people well.The ...

# %%
exp_nlp102 = setup(data = data, target = 'answerText', session_id = 123,
                   custom_stopwords = ['would', 'want', 'usd', 'many', 'also', 'make', 
                                       'find','see', 'say', 'often', 'much', 'go', 'come',
                                       'thought', 'even','learn','happen','much','let','know','thing','need','take'
                                      , 'get','try','ask','maybe','keep','end','way','suggest','likely','area','part',
                                      'consider','right','able','could','tell','seem','use','sometimes','think','look','self','lot','new','well','give',
                                      'start'],
                   log_experiment = True, experiment_name = 'kiva1')
# Out:
# <style  type="text/css" >
# </style><table id="T_93719_" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_93719_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_93719_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                                 <td id="T_93719_row1_col0" class="data row1 col0" >Documents</td>
#                         <td id="T_93719_row1_col1" class="data row1 col1" >2129</td>
#             </tr>
#             <tr>
#                                 <td id="T_93719_row2_col0" class="data row2 col0" >Vocab Size</td>
#                         <td id="T_93719_row2_col1" class="data row2 col1" >6745</td>
#             </tr>
#             <tr>
#                                 <td id="T_93719_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#                         <td id="T_93719_row3_col1" class="data row3 col1" >True</td>
#             </tr>
#     </tbody></table>

# %%
lda = create_model('lda', num_topics = 16)

# %%
# to find the best suited number of topic for our case using intrinsic evalution
#tuned_unsupervised = tune_model(model = 'lda', multi_core = True)

# %%
# using extrinsic evaluation using classifier
#tuned_classification = tune_model(model = 'lda', multi_core = True, supervised_target = 'answerText')

# %%
plot_model(lda, plot = 'topic_distribution')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="11bad99c-2c21-44d3-b3bf-0c12da1073bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11bad99c-2c21-44d3-b3bf-0c12da1073bf")) {                    Plotly.newPlot(                        "11bad99c-2c21-44d3-b3bf-0c12da1073bf",                        [{"alignmentgroup": "True", "customdata": [["parent, child, personal, group, progress, afraid, young, pass, valuable, measure"], ["people, really, emotion, important, comfortable, call, fit, actually, remember, may"], ["behavior, depend, human, harm, finally, sadness, network, addiction, utilize, resolution"], ["therapist, therapy, client, cry, process, goal, experience, begin, counselor, offer"], ["relationship, person, love, partner, people, together, couple, hurt, mean, willing"], ["time, friend, sure, idea, meet, set, enough, may, connection, sexual"], ["feel, talk, feeling, question, understand, person, trust, support, may, first"], ["help, may, work, good, issue, counselor, life, session, counseling, first"]], "hovertemplate": "Topic=%{x}<br>Documents=%{y}<br>Keyword=%{customdata[0]}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Topic 2", "Topic 4", "Topic 6", "Topic 7", "Topic 11", "Topic 13", "Topic 14", "Topic 15"], "xaxis": "x", "y": [1, 47, 2, 23, 29, 39, 211, 1777], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.44444444 ...

# %%
plot_model()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="eac395cd-82f9-4938-bc2d-28e9eb651a90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("eac395cd-82f9-4938-bc2d-28e9eb651a90")) {                    Plotly.newPlot(                        "eac395cd-82f9-4938-bc2d-28e9eb651a90",                        [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["feel", "may", "help", "relationship", "time", "good", "therapist", "people", "work", "life", "talk", "feeling", "person", "therapy", "change", "experience", "issue", "question", "anxiety", "first", "love", "important", "support", "situation", "client", "partner", "child", "really", "understand", "sound", "counselor", "emotion", "parent", "trust", "care", "friend", "different", "problem", "process", "helpful", "reason", "family", "fear", "possible", "mean", "depression", "live", "counseling", "difficult", "great", "place", "answer", "step", "couple", "become", "session", "behavior", "emotional", "sense", "always", "address", "together", "long", "mind", "seek", "idea", "open", "stress", "normal", "sure", "hard", "husband", "hear", "call", "hope", "conversation", "focus", "begin", "wish", "hurt", "concern", "safe", "decide", "accept", "deal", "healthy", "cry", "believe", "boyfriend", "listen", "write", "example", "show", "symptom", "still", "never", "offer", "happy", "goal", "day"], "y": [2524, 2169, 1591, 1455, 1355, 1240, 1078, 1064, 1042, 897, 781, 771, 719, 651, 612, 604, 590, 572, 554, 536, 522, 487, 472, 468, 463, 436, 434, 432, 432, 405, 403, 400, 387, 380, 377, 376, 374, 369, 335, 334, 331, 327, 327, 323, 319, 315, 312, 311, 306, 295, 285, 283, 277, 276, 258, 253, 253, 252, 246, 245, 244, 243, 243, 242, 240, 239, 237, 236, 236, 236, 233, 233, 229, 228, 227, 227, 226, 223, 223, 218, 218, 217, 213, 211, 209, 208, 208, 204, 202, 200, 200, 198, 193, 193, 192, 192, 191, 190, 190, 188]}],                        {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.88888 ...

# %%
 mplot = get_model_plot()
 print(mplot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fe947a526676> in <module>
# ----> 1 mplot = get_model_plot()
#       2 print(mplot)
#
# NameError: name 'get_model_plot' is not defined

# %%
#tuned_unsupervised = tune_model(model = 'lda', multi_core = True)

# %%
plot_model(plot = 'bigram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="123deded-d1ee-42dd-88af-2f30485ede43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("123deded-d1ee-42dd-88af-2f30485ede43")) {                    Plotly.newPlot(                        "123deded-d1ee-42dd-88af-2f30485ede43",                        [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["good luck", "may help", "may feel", "therapist help", "first step", "may helpful", "feel comfortable", "feel good", "feel safe", "answer question", "therapist may", "help feel", "spend time", "help understand", "wish good", "good idea", "may good", "seek help", "good time", "good therapist", "time feel", "professional help", "issue address", "friend family", "people feel", "anxiety depression", "work together", "person feel", "relationship feel", "support group", "talk therapist", "therapy help", "therapist feel", "cry therapy", "counseling help", "help people", "seek professional", "therapist specialize", "work therapist", "live life", "first time", "depression anxiety", "relationship may", "time may", "feel anxious", "work issue", "good fit", "reach help", "may time", "therapist work", "couple therapy", "feel less", "life feel", "feeling may", "talk feel", "feel may", "may talk", "question may", "feel feel", "feel sad", "counselor help", "therapy session", "long time", "feel alone", "feel love", "help work", "counselor may", "question answer", "client feel", "great question", "therapist good", "feel guilty", "client may", "help cope", "issue may", "good wish", "relationship work", "hope helpful", "feel overwhelmed", "couple therapist", "may experience", "abusive relationship", "therapeutic relationship", "emotional pain", "work relationship", "first place", "good enough", "work client", "change life", "understand feel", "time work", "good care", "life may", "therapy may", "local therapist", "may benefit", "person may", "partner feel", "people may", "safe place"], "y": [178, 124, 123, 110, 97, 82, 73, 70, 65, 61, 60, 59, 55, 51, 50, 48, 47, 46, 45, 44, 44, 44, 43, 43, 42, 42, 41, 39, 39, 39, 39, 38, 37, 35, 35, 35, 33, 32, 32, 32, 32, 32, 31, 31, 30, 30, 30, 30, 30, 29, 29, 29, 29, 29, 28, 28, 28, 28, 28, 28, 28, 28, 27, 27, 27, 27, 26, 26, 26, 26, 26, 25, 25, 25, 25, 25, 25, 25, 25, 24, 24, 24, 24, 24, 24, 24, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 22, 22, 22]}],                        {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555 ...

# %%
#plot_model(lda, plot = 'frequency', topic_num = 'Topic 4')

# %%
plot_model(lda, plot = 'tsne')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a66d087b-edd5-49da-a2cc-65180dbdfc08" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a66d087b-edd5-49da-a2cc-65180dbdfc08")) {                    Plotly.newPlot(                        "a66d087b-edd5-49da-a2cc-65180dbdfc08",                        [{"hovertemplate": "Dominant_Topic=Topic 11<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>", "legendgroup": "Topic 11", "marker": {"color": "#636efa", "opacity": 0.7, "symbol": "circle"}, "mode": "markers", "name": "Topic 11", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.3932623863220215, 6.375630855560303, 6.502670764923096, 1.4721261262893677, 5.989539623260498, 7.063321113586426, 6.762245178222656, 6.602309226989746, 7.067698001861572, 7.118068218231201, 6.145533561706543, 6.953693389892578, 6.555027484893799, 6.769626140594482, 5.8812665939331055, 5.402920722961426, 6.179883003234863, 5.722455024719238, 5.491776466369629, 2.3997321128845215, 7.033597946166992, 6.451574802398682, 3.051710844039917, 7.139448165893555, 7.076183795928955, 5.945456027984619, 6.573976039886475, 6.509149074554443, 5.689096450805664], "y": [2.0361781120300293, 2.3249735832214355, 0.8171424269676208, 7.87116813659668, -0.4630361795425415, -1.0801868438720703, 0.979676365852356, 1.1235606670379639, -0.7671552896499634, 0.7176725268363953, -1.2329261302947998, 0.2732698619365692, 1.986281156539917, -1.0219913721084595, -0.7761729955673218, 1.8727761507034302, 1.7058181762695312, -1.6795076131820679, 1.461984395980835, 0.5698745846748352, -0.9986560344696045, 0.8286982774734497, 0.3754677176475525, 0.6039226055145264, 0.043543413281440735, 0.7996280789375305, 0.1594277024269104, 0.46213358640670776, -1.7495436668395996], "z": [-15.203089714050293, -15.636385917663574, -17.618623733520508, -10.210576057434082, -16.634489059448242, -16.842731475830078, -15.079971313476562, -13.405056953430176, -16.800235748291016, -15.690997123718262, -14.229973793029785, -16.58905029296875, -14.872529983520508, -16.594650268554688, -14.793362617492676, -15.332347869873047, -15.752737998962402, -14.732034683227539, -15.266345024108887, -15.694565773010254, -16.78254508972168, -17.55551528930664, -15.643865585327148, -15.36168384552002, -16.46120262145996, -14.183636665344238, -17.48691177368164, -17.536510467529297, -14.730524063110352]}, {"hovertemplate": "Dominant_Topic=Topic 13<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>", "legendgroup": "Topic 13", "marker": {"color": "#EF553B", "opacity": 0.7, "symbol": "circle"}, "mode": "markers", "name": "Topic 13", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-5.07106351852417, -6.117143630981445, -3.1181461811065674, -5.436974048614502, -2.0666592121124268, -4.154013633728027, -7.907786846160889, -5.186695575714111, -7.923255920410156, -6.735727787017822, -4.244885444641113, -5.893057346343994, -2.67840313911438, -4.456303596496582, -6.318150997161865, -7.862557888031006, -2.103994607925415, -6.605508327484131, -2.9896514415740967, -7.285763740539551, -6.402195453643799, -6.472459316253662, -7.645559310913086, -6.557976245880127, -5.909042835235596, -7.354629039764404, -6.159965991973877, -6.934055805206299, -4.980820655822754, -8.700791358947754, -4.828386306762695, -7.225427150726318, -6.963893413543701, -3.1184661388397217, -7.526392459869385, -3.0746288299560547, -7.182901382446289, -1.4836827516555786, -3.619352340698242], "y": [7.054986476898193, 5.202889919281006, 5.7650957107543945, 4.081287860870361, 6.576328277587891, 7.210371494293213, 4.175082683563232, 5.3147454261779785, 5.965068817138672, 3.2552096843719482, 6.752094268798828, 4.921940803527832, 6.355946063995361, 2.951409339904785, 5.6267170906066895, 5.824648380279541, 7.184787273406982, 6.205239295 ...

# %%
plot_model(lda, plot = 'umap')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
